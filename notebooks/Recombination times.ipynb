# %% [markdown]
# # Estimate recombination times for ions

# %% [markdown]
# Formula for recombination time from Nicastro (1999)

# %%
def t_rec(alpha, n_e):
    return 1./alpha/n_e

# %% [markdown]
# For Fe:

# %%
# Out:
# 36982.2485207
